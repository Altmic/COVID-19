# %% [markdown]
# <a href="https://colab.research.google.com/github/Altmic/COVID-19/blob/master/Astronomy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num_list=[42,46,54,65,90]
slices=num_list[3]
print(num_list)
print(slices)
total=num_list[0]+num_list[1]
print(total)
# Out:
# [42, 46, 54, 65, 90]
# 65
# 88

# %%
fname='Michael'
lname='Atmannsberger'
print(fname+' '+lname)
# Out:
# Michael Atmannsberger

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(300)
y = x**1 + np.sin(3*x)
plt.plot(x,y)
plt.show()
